# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
cd C:\Users\VRUTANT\Desktop
# Out:
# C:\Users\VRUTANT\Desktop

# %%
df=pd.read_csv("melbourne_housing.csv")

# %%
df
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03-09-2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.drop(["Address","Date","YearBuilt","Lattitude","Longtitude"],axis="columns",inplace=True)

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df[['Propertycount','Bedroom2','Bathroom','Distance','Car']]=df[['Propertycount','Bedroom2','Bathroom','Distance','Car']].fillna(0)

# %%
df
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             0
# Postcode             1
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        0
# dtype: int64

# %%
mean=df['Landsize'].mean()

# %%
df['Landsize'].fillna(df['Landsize'].mean(),inplace=True)

# %%
df
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Postcode  Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %%
df['BuildingArea'].fillna(df['BuildingArea'].mean(),inplace=True)

# %%
df
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Postcode  Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Price            7610
# Method              0
# SellerG             0
# Distance            0
# Postcode            1
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# CouncilArea         3
# Regionname          3
# Propertycount       0
# dtype: int64

# %%
df['CouncilArea']=df['CouncilArea'].fillna(method='ffill')

# %%
df['Regionname']=df['Regionname'].fillna(method='ffill')

# %%
df.dropna(inplace=True)

# %%
df['Method'].unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 2          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 4          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 5          3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 6          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 34852      4  1480000.0       6.3    3013.0       4.0       1.0  3.0
# 34853      2   888000.0       6.3    3013.0       2.0       2.0  1.0
# 34854      2   705000.0       6.3    3013.0       2.0       1.0  2.0
# 34855      3  1140000.0       6.3    3013.0       0.0       0.0  0.0
# 34856      2  1020000.0       6.3    3013.0       2.0       1.0  0.0
#
#          Landsize  BuildingArea  Propertycount  ...  \
# 1      202.000000      160.2564         4019.0  ...
# ...

# %%
df.shape
# Out:
# (27246, 746)

# %%
df.corr()
# Out:
#                                           Rooms     Price  Distance  Postcode  \
# Rooms                                  1.000000  0.465242  0.284298  0.081328
# Price                                  0.465242  1.000000 -0.211384  0.044950
# Distance                               0.284298 -0.211384  1.000000  0.489734
# Postcode                               0.081328  0.044950  0.489734  1.000000
# Bedroom2                               0.558454  0.301545  0.157722  0.052577
# ...                                         ...       ...       ...       ...
# Regionname_Northern Victoria           0.038175 -0.052623  0.252170  0.234409
# Regionname_South-Eastern Metropolitan  0.061366 -0.061187  0.434860  0.226285
# Regionname_Southern Metropolitan      -0.064027  0.363644 -0.230918  0.265563
# Regionname_Western Metropolitan        0.045859 -0.172657 -0.027869 -0.355316
# Regionname_Western Victoria            0.019942 -0.057250  0.170966  0.119848
#
# ...

# %%
x=df.drop('Price',axis=1)
y=df['Price']

# %%
y
# Out:
# 1        1480000.0
# 2        1035000.0
# 4        1465000.0
# 5         850000.0
# 6        1600000.0
#            ...
# 34852    1480000.0
# 34853     888000.0
# 34854     705000.0
# 34855    1140000.0
# 34856    1020000.0
# Name: Price, Length: 27246, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape,y_train.shape
# Out:
# ((21796, 745), (21796,))

# %%
x_test.shape,y_test.shape
# Out:
# ((5450, 745), (5450,))

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.684445463717812

# %%
lr.score(x_test,y_test)
# Out:
# 0.6531866759914641

# %%
y_pre=lr.predict(x_test)
y_pre
# Out:
# array([ 428113.30211184, 1106852.19900564, 1234218.26514405, ...,
#         481425.74895981, 1258449.69612657, 1752568.41659514])

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
ridge_reg=Ridge(alpha=50,max_iter=100)
ridge_reg.fit(x_train,y_train)
# Out:
# Ridge(alpha=50, max_iter=100)

# %%
ridge_reg.score(x_test,y_test)
# Out:
# 0.647972074610458

# %%
ridge_reg.score(x_train,y_train)
# Out:
# 0.6689471410535701

# %%
lasso_reg=Lasso(alpha=50,max_iter=10000)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=50, max_iter=10000)

# %%
lasso_reg.score(x_train,y_train)
# Out:
# 0.680361806980061

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.6538615091183052

# %%
lr.intercept_
# Out:
# -41208.42671010364

# %%
lr.coef_
# Out:
# array([ 2.67163810e+05, -4.74055857e+04,  3.07542126e+02, -8.86089917e+04,
#         1.30692528e+05,  4.31673847e+04,  2.18340224e+00,  3.82605879e+01,
#        -4.25649034e+01,  1.77489967e+05, -5.71186380e+04, -2.17517018e+05,
#         1.90392178e+05,  4.69532932e+04, -3.24756131e+04,  2.58651688e+05,
#         8.92701835e+04, -5.66042302e+04, -1.47371335e+05,  1.05274025e+05,
#         2.12939342e+04, -2.09934565e+05, -1.08137324e+05,  9.70425114e+04,
#        -2.92203128e+05, -2.59258161e+05, -1.86602163e+05,  1.18505013e+05,
#        -2.25566319e+05,  1.45409745e+05,  8.19439344e+04,  1.21220127e+05,
#         3.33117937e+04, -1.61088455e+05, -4.38979295e+04,  1.80263042e+05,
#        -4.79028639e+05,  1.79901257e+05,  2.70535644e+05,  5.10786919e+05,
#         1.49669097e+05,  2.21498543e+05, -2.08239108e+05, -6.01101164e+04,
#         2.29359128e+05,  3.28974241e+05, -3.34863151e+04,  1.68722487e+05,
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from math import sqrt

# %%
r2_score(y_test,y_pre)
# Out:
# 0.6531866759914641

# %%
mean_squared_error(y_test,y_pre)
# Out:
# 144130508710.41983

# %%
mean_absolute_error(y_test,y_pre)
# Out:
# 233974.04961011218
